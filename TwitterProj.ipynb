# %%
# http://www.tweepy.org/
import sys 
# !{sys.executable} -m pip install tweepy
# !{sys.executable} -m pip install jsonpickle
# !{sys.executable} -m pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tweepy

# Replace the API_KEY and API_SECRET with your application's key and secret.
API_KEY = "2t5WrolT6cQg4MMMJacv2k9nf" 
API_SECRET="0vWFAxWbwK1IIXGkFrb2yYtAE8AbOrjRpEeAzxeEJWDOf4DOaM" 

access_token="12587852-pvx0DwRsbZWanlj9bhLx0de7yXLINi79GXMfAr8l0" 
access_token_secret="Sdzj4i22WvaR8xboHbbpGjUUzMPWYOKWijbVwbEzuA2TH" 


auth = tweepy.AppAuthHandler(API_KEY, API_SECRET)
#auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
 
if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)

# %%
import sys
import jsonpickle
import os

searchQuery = '#DPI'  # this is what we're searching for
maxTweets = 20000 # some arbitrary large number
tweetsPerQry = 100  # this is the max the API permits
fName = 'tweets2.json' # we'll store the tweets in a text file.

# If results from a specific ID onwards are reqd, set since_id to that ID.
# else default to no lower limit, go as far back as API allows
sinceId = None

# If results only below a specific ID are, set max_id to that ID.
# else default to no upper limit, start from the most recent tweet matching the search query.
max_id = -1

tweetCount = 0
print("Downloading max {0} tweets".format(maxTweets))
with open(fName, 'w') as f:
    while tweetCount < maxTweets:
        try:
            if (max_id <= 0):
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry)
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            since_id=sinceId)
            else:
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1))
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1),
                                            since_id=sinceId)
            if not new_tweets:
                print("No more tweets found")
                break
            for tweet in new_tweets:
                f.write(jsonpickle.encode(tweet._json, unpicklable=False) +
                        '\n')
            tweetCount += len(new_tweets)
            print("Downloaded {0} tweets".format(tweetCount))
            max_id = new_tweets[-1].id
        except tweepy.TweepError as e:
            # Just exit if any error
            print("some error : " + str(e))
            break

print ("Downloaded {0} tweets, Saved to {1}".format(tweetCount, fName))
# Out:
# ...
# Downloaded 100 tweets
# Downloaded 200 tweets
# Downloaded 300 tweets
# Downloaded 390 tweets
# No more tweets found
# Downloaded 390 tweets, Saved to tweets2.json

# %%
import json

with open('tweets2.json') as fp:
    lines = fp.readlines()

texto=[]
for line in lines:
    try:
        json_data = json.loads(line)
        #print(json_data['text'])
        texto.append(json_data)
    except:
        pass
type(texto)
#len(texto)
#texto.split()
# Out:
# list

# %%
import re
texto_list= []
for t in range(0,len(texto)):
    listica = texto[t]['text']
    texto_list.append(listica)

texto_low = []
for h in texto_list:
    try:
        hh= h.lower()
        hhh=hh
        texto_low.append(hhh)
    except:
        pass
    
texto_imp=[]
for w in range(1,len(texto_low)):
    ee = re.sub(r'\b\w{1,3}\b', '', texto_low[w])
    
    texto_imp.append(ee) 
print(texto_imp)

#Eliminamos los tweets repetidos
#texto_ND=[]
#for x in texto_list:
    #if x not in texto_ND:
        #texto_ND.append(x)

#len(texto_ND)
# Out:
# [' design ‘good’ #, countries  build   ‘open #digital ecosystems’ approach  focus  getting three … https://./oxydsgiwb0', " @dalbergtweet: think   your digital  authentication enables   open  bank account. that'  example  #digitalpublicinfras…", ' most hyped  next month gonna  @plcu_official download     order -paid visa card! \n native… https://./y3dk2uqjwk', '@uargentini  dice  differenza esiste   medico  vaccinato   protegge  protegge  altri  ques… https://./i1511chuif', ' most hyped chain next month gonna  @plcu_official $plcu inflation stops soon  price will moon. when people… https://./wxfnzcbjgg', ' estonian experience  shown  that #  #digitalpublicgoods  both viable  valuable tools   … https://./guxdmcyapt', ' (direct, plan  improve). cultivate  apply throughout service management careers. better leaders  indiv… https://./dtkj6jxurf', ' very hard  hours!      …👏🏼 looking forward  next season  gtr24h # #lmp2 #endurance… https://./epneukfoaa', 'india’ unified payment interface 
# ...

# %%
#Texto split... 
#mm=texto_list[0:20000]

texto_split=[] 
for t in texto_imp:
    tt= t.split(' ')
    texto_split.append(tt)
print(texto_split)
# Out:
# [['', 'design', '‘good’', '#,', 'countries', '', 'build', '', '', '‘open', '#digital', 'ecosystems’', 'approach', '', 'focus', '', 'getting', 'three', '…', 'https://./oxydsgiwb0'], ['', '@dalbergtweet:', 'think', '', '', 'your', 'digital', '', 'authentication', 'enables', '', '', 'open', '', 'bank', 'account.', "that'", '', 'example', '', '#digitalpublicinfras…'], ['', 'most', 'hyped', '', 'next', 'month', 'gonna', '', '@plcu_official', 'download', '', '', '', '', 'order', '-paid', 'visa', 'card!', '\n', 'native…', 'https://./y3dk2uqjwk'], ['@uargentini', '', 'dice', '', 'differenza', 'esiste', '', '', 'medico', '', 'vaccinato', '', '', 'protegge', '', 'protegge', '', 'altri', '', 'ques…', 'https://./i1511chuif'], ['', 'most', 'hyped', 'chain', 'next', 'month', 'gonna', '', '@plcu_official', '$plcu', 'inflation', 'stops', 'soon', '', 'price', 'will', 'moon.', 'when', 'people…', 'https://./wxfnzcbjgg'], ['', 'estonian', 'experience', '', 'shown', '', 'that', '#', '', '#digitalpublicgo
# ...

# %%
#from nltk.tokenize import sent_tokenize, word_tokenize
#from nltk.corpus import stopwords

#Quitamos stopwords
#stopWords = set(stopwords.word("spanish"))
#words = word_tokenize(texto_split)

# %%
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 1837-291B
#
#  Directorio de C:\Users\prestamour\Desktop\Proyecto
# No se encuentra el archivo
