# %% [markdown]
# **Combining all into one large and hopefully final DPI_dataset**

# %%
# import requests
import pandas as pd
import numpy as np 
import os

# %%
# Import Drive API and authenticate.
from google.colab import drive
# Mount your Drive to the Colab VM.
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# path = ('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/')
# csv_files = os.listdir(path)
# csv_files

# %%
list_df = list() 

# for file in csv_files:
#   df = pd.read_csv(path + '/' + file) 
#   df = df.set_index('Date')
#   list_df.append(df)

# list_df 

### THESE PATHS ARE TO THOSE WHERE RETURNS FOR PRICES AND ABS. CHANGES FOR % METRICS WERE CALCULATED 
benchmarks = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/benchmarks_returns.csv')
benchmarks = benchmarks.set_index('Date')
list_df.append(benchmarks)

underlying = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/underl_assets_returns.csv')
underlying = underlying.set_index('Date')
list_df.append(underlying)

fear_index = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/crypto_fear_index_historical.csv')
fear_index = fear_index.set_index('Date')
list_df.append(fear_index)

DPI_aum_NF = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/DPI_aum_netflow.csv')
DPI_aum_NF = DPI_aum_NF.set_index('Date')
list_df.append(DPI_aum_NF)

market_data = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/market_data_cleaned_FINAL.csv')
market_data = market_data.set_index('Date')
list_df.append(market_data)


### THESE PATHS ARE TO THOSE THAT HAVE OWN ABSOLUTE VALUES (LIKE PRICE, ETC.)
# benchmarks = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/benchmarks_returns_222.csv')
# benchmarks = benchmarks.set_index('Date')
# list_df.append(benchmarks)

# underlying = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/underl_assets_returns_222.csv')
# underlying = underlying.set_index('Date')
# list_df.append(underlying)

# fear_index = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/crypto_fear_index_historical.csv')
# fear_index = fear_index.set_index('Date')
# list_df.append(fear_index)

# DPI_aum_NF = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/DPI_aum_netflow_2.csv')
# DPI_aum_NF = DPI_aum_NF.set_index('Date')
# list_df.append(DPI_aum_NF)

# market_data = pd.read_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/market_data_cleaned_FINAL_222.csv')
# market_data = market_data.set_index('Date')
# list_df.append(market_data)


list_df
# Out:
# [            BNB_returns  WBTC_returns  WETH_returns
#  Date
#  2020-09-10          NaN           NaN           NaN
#  2020-09-11    -0.021759     -0.007025     -0.001166
#  2020-09-12     0.122654      0.006395      0.021024
#  2020-09-13     0.125158      0.001466      0.000402
#  2020-09-14     0.015966      0.009599     -0.009422
#  ...                 ...           ...           ...
#  2022-10-01    -0.008077     -0.010242     -0.010551
#  2022-10-02     0.001597     -0.004982     -0.014882
#  2022-10-03     0.011780      0.004163      0.000310
#  2022-10-04     0.019479      0.031821      0.029967
#  2022-10-05     0.006009      0.009250      0.002096
#
#  [756 rows x 3 columns],
#              UNI_returns  AAVE_returns  MKR_returns  SNX_returns  COMP_returns
#  Date
#  2020-09-10          NaN           NaN          NaN          NaN           NaN
#  2020-09-11          NaN           NaN    -0.026291     0.064174     -0.037999
# ...

# %%
  # concatenating all and saving into csv (hopefully will be good dataframe)
DPI_dataset = pd.DataFrame() 

for df in list_df: 
     DPI_dataset = pd.concat([DPI_dataset, df], axis=1)

# %%
DPI_dataset
# Out:
#             BNB_returns  WBTC_returns  WETH_returns  UNI_returns  \
# Date
# 2020-09-10          NaN           NaN           NaN          NaN
# 2020-09-11    -0.021759     -0.007025     -0.001166          NaN
# 2020-09-12     0.122654      0.006395      0.021024          NaN
# 2020-09-13     0.125158      0.001466      0.000402          NaN
# 2020-09-14     0.015966      0.009599     -0.009422          NaN
# ...                 ...           ...           ...          ...
# 2018-01-30          NaN           NaN           NaN          NaN
# 2018-01-31          NaN           NaN           NaN          NaN
# 2018-04-14          NaN           NaN           NaN          NaN
# 2018-04-15          NaN           NaN           NaN          NaN
# 2018-04-16          NaN           NaN           NaN          NaN
#
#             AAVE_returns  MKR_returns  SNX_returns  COMP_returns  fear_index  \
# Date
# 2020-09-10           NaN          NaN          NaN           NaN        -1.0
# ...

# %%
DPI_new = DPI_dataset.copy()

DPI_new.replace([np.inf, -np.inf], np.nan, inplace=True)
DPI_new = DPI_new.dropna()

DPI_new
# Out:
#             BNB_returns  WBTC_returns  WETH_returns  UNI_returns  \
# Date
# 2020-10-14    -0.004369     -0.002947     -0.004708    -0.043257
# 2020-10-15     0.007754      0.000099     -0.009272    -0.061386
# 2020-10-16    -0.018294     -0.004970     -0.018980     0.027358
# 2020-10-17    -0.006767     -0.001088     -0.005762    -0.029414
# 2020-10-18     0.012301      0.008247      0.015474     0.033553
# ...                 ...           ...           ...          ...
# 2022-09-19    -0.038131     -0.043422     -0.064125    -0.082194
# 2022-09-20     0.015898      0.009786      0.017460     0.008146
# 2022-09-22     0.005705     -0.002194     -0.033138     0.050350
# 2022-09-23     0.018410      0.004411      0.022824     0.029652
# 2022-09-27     0.021501      0.037645      0.037178     0.114878
#
#             AAVE_returns  MKR_returns  SNX_returns  COMP_returns  fear_index  \
# Date
# 2020-10-14      0.029752    -0.005880    -0.018842     -0.039761         0.0
# ...

# %%
DPI_new.drop(columns='net_flow', inplace=True) 
DPI_new
# Out:
#             BNB_returns  WBTC_returns  WETH_returns  UNI_returns  \
# Date
# 2020-10-14    -0.004369     -0.002947     -0.004708    -0.043257
# 2020-10-15     0.007754      0.000099     -0.009272    -0.061386
# 2020-10-16    -0.018294     -0.004970     -0.018980     0.027358
# 2020-10-17    -0.006767     -0.001088     -0.005762    -0.029414
# 2020-10-18     0.012301      0.008247      0.015474     0.033553
# ...                 ...           ...           ...          ...
# 2022-09-19    -0.038131     -0.043422     -0.064125    -0.082194
# 2022-09-20     0.015898      0.009786      0.017460     0.008146
# 2022-09-22     0.005705     -0.002194     -0.033138     0.050350
# 2022-09-23     0.018410      0.004411      0.022824     0.029652
# 2022-09-27     0.021501      0.037645      0.037178     0.114878
#
#             AAVE_returns  MKR_returns  SNX_returns  COMP_returns  fear_index  \
# Date
# 2020-10-14      0.029752    -0.005880    -0.018842     -0.039761         0.0
# ...

# %%
# this saving is for returns/changes
DPI_new.to_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/DPI_dataset_final.csv') 

# this saving is for absolute prices/values/metrics
# DPI_new.to_csv('/content/gdrive/My Drive/IndexCoop Capstone/DPI analysis/datasets/DPI_dataset_final_222.csv')
